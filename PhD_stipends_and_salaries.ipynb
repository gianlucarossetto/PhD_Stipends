# %% [markdown]
# <a href="https://colab.research.google.com/github/gianlucarossetto/PhD_Stipends/blob/main/PhD_stipends_and_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PhD stipenss and salaries all around the World
#
# I am a 2nd year PhD student. My PhD is founded by a sholarship.
# I'd like to analyse stipend and salaries of PhD's all around the world.
#
# After a Google seach I found Kaggle (www.kaggle.com), a free access wesite with plenty of datasets.
#
# In Kaggle I found a dataset, updated 7 mounths ago (today is 25 april 2023)
# I downloaded this dataset, uploaded it in my GitHub repository, and started to analyse it.

# %% [markdown]
# In my first step I imported libaries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# As second step I loaded the dataset from GitHub

# %%
url = ('https://raw.githubusercontent.com/gianlucarossetto/PhD_Stipends/main/csv')

# %%
dataset = pd.read_csv(url)

# %% [markdown]
# We are going now to take a look about the type of variables.......

# %%
dataset.head()
# Out:
#                                        University  \
# 0  Georgia Institute of Technology (Georgia Tech)
# 1         University of Southern California (USC)
# 2  Georgia Institute of Technology (Georgia Tech)
# 3                              University of Utah
# 4     Texas A&amp;M; University - College Station
#
#                                 Department Overall Pay  LW Ratio  \
# 0      Electrical and Computer Engineering     $29,000      1.25
# 1                             Gerontology      $37,850      1.46
# 2      Electrical and Computer Engineering      $2,550      0.11
# 3                    Physics and astronomy     $30,000      1.35
# 4  Veterinary Physiology and Pharamacology     $24,000       NaN
#
#   Academic Year Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay  \
# 0     2022-2023          2nd        $30,600           NaN           NaN
# 1     2022-2023          1st        $38,000           NaN           NaN
# ...

# %%
dataset.describe()
# Out:
#            LW Ratio
# count  12206.000000
# mean       1.171822
# std        3.752636
# min      -34.010000
# 25%        0.880000
# 50%        1.130000
# 75%        1.330000
# max      265.030000

# %% [markdown]
# I created then some Histograms to visualize data

# %%
sns.displot(dataset['Overall Pay'], kde=False).fig.suptitle('Histogram of Overall Pay')
plt.show()

# %% [markdown]
# .....may be interesting also visualize how much are Fees......

# %%
sns.displot(dataset['Fees'], kde=False).fig.suptitle('Fees')
plt.show()

# %% [markdown]
# i think it is better to visualize Fees in a Boxplot:

# %%
dataset.groupby(['Department','University']).size()
# Out:
# Department              University
#  Chemical Engineering   Purdue University - West Lafayette            1
#  Chemistry              University of Florida (UF)                    1
#  Faculty of Forestry    University of Belgrade                        1
#  History                University of California - Irvine (UCI)       1
# 12570 - Psychology      Vanderbilt University                         1
#                                                                      ..
# structural biology      University at Buffalo - SUNY                  1
# structural engineering  Illinois State University (ISU)               1
# sustainability          Arizona State University (ASU)                1
# system engineering      University of Virginia (UVA)                  1
# veterinary medicine     University of Minnesota - Twin Cities (UM)    1
# Length: 8373, dtype: int64

# %% [markdown]
# List unique values in the dataset['Department'] column

# %%
dataset.Department.unique()
# Out:
# array(['Electrical and Computer Engineering', 'Gerontology ',
#        'Physics and astronomy', ...,
#        'Computational Biology & Bioinformatics',
#        'Program in Computational Biology and Bioinformatics', 'EBIO'],
#       dtype=object)

# %% [markdown]
# List unique values in the dataset['University'] column

# %%
dataset.University.unique()
# Out:
# array(['Georgia Institute of Technology (Georgia Tech)',
#        'University of Southern California (USC)', 'University of Utah',
#        'Texas A&amp;M; University - College Station',
#        'Baylor University (BU)', 'Colorado State University (CSU)',
#        'Central Michigan University (CMU)', 'University of Toronto',
#        'Washington University in St. Louis (Wash U)',
#        'Northwestern University (NU)', 'Clark University',
#        'University of California - Riverside (UCR)',
#        'University of California - Irvine (UCI)',
#        'University of California - San Francisco (UCSF)',
#        'George Mason University (GMU)', 'University of Kansas (KU)',
#        'Michigan State University (MSU)', 'Brown University', nan,
#        'South Dakota State University (SDSU)', 'Harvard University (HU)',
#        'University of Maryland - College Park (UMD)',
#        'Cleveland State University (CSU)', 'University of Pittsburgh',
# ...

# %% [markdown]
# List unique values in the dataset['Fees'] column

# %%
dataset.Fees.unique()
# Out:
# array(['$1,600', '$150', nan, ..., '$5,193', '$5,330', '$4,958'],
#       dtype=object)
